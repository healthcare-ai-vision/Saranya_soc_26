# %%
denoise1 = cv2.GaussianBlur(noisy1, (5,5), 0)
denoise2 = cv2.GaussianBlur(noisy2, (5,5), 0)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(denoise1, cmap='gray')
plt.title("Denoised Puppy")

plt.subplot(1,2,2)
plt.imshow(denoise2, cmap='gray')
plt.title("Denoised X-ray")

plt.show()

# %%
noise1 = np.random.normal(0, 25, gray1.shape).astype(np.uint8)
noise2 = np.random.normal(0, 25, gray2.shape).astype(np.uint8)

noisy1 = cv2.add(gray1, noise1)
noisy2 = cv2.add(gray2, noise2)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(noisy1, cmap='gray')
plt.title("Noisy Puppy")

plt.subplot(1,2,2)
plt.imshow(noisy2, cmap='gray')
plt.title("Noisy X-ray")

plt.show()

# %%
edges1 = cv2.Canny(gray1, 100, 200)
edges2 = cv2.Canny(gray2, 100, 200)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(edges1, cmap='gray')
plt.title("Edges - Puppy")

plt.subplot(1,2,2)
plt.imshow(edges2, cmap='gray')
plt.title("Edges - X-ray")

plt.show()

# %%
resize1 = cv2.resize(img1_rgb, (200, 200))
resize2 = cv2.resize(img2_rgb, (200, 200))

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(resize1)
plt.title("Resized Puppy")

plt.subplot(1,2,2)
plt.imshow(resize2)
plt.title("Resized X-ray")

plt.show()

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.hist(gray1.ravel(), bins=256)
plt.title("Histogram - Puppy")

plt.subplot(1,2,2)
plt.hist(gray2.ravel(), bins=256)
plt.title("Histogram - X-ray")

plt.show()

# %%
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(gray1, cmap='gray')
plt.title("Grayscale Puppy")

plt.subplot(1,2,2)
plt.imshow(gray2, cmap='gray')
plt.title("Grayscale X-ray")

plt.show()

# %%
img1 = cv2.imread("sample image1.jpg")   # Puppy
img2 = cv2.imread("sample image 2.jpg")  # X-ray

img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(img1_rgb)
plt.title("Puppy Image")

plt.subplot(1,2,2)
plt.imshow(img2_rgb)
plt.title("X-ray Image")

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
